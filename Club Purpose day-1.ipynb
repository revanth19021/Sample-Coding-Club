# %%
# a="hell->revanth->world"
# print(input().split('****'))

a,b=map(int,input().split('->'))
print(a,b)

# %%
# PFSD 
end to end development is clled full stack
frontend+backend+database

# PFSD   - due to more builtin modules
Frontend- html
backend- > Flask,Django(Python)
database-> Mongodb, MYSql

frontend -> creating a user interactive webpages Ex:html, React, Angular, Vuejs ,JS
backend  -> Implementting the main Logic or providing security to the webapp Ex: Python, Java, NodeJS, ExpressJs
database -> Store the data Ex: mongodb, mysql, CassandraDb
# Mean Stack -> M-> MongoDb, E-> ExpressJs, A--> Angular N-> NodeJs
# MERN Stack -> M-> MongoDb, E-> ExpressJs, R-> ReactJs, N-> NodeJs
# Java Full Stack -> JSP(Javaserverpages)-> Frontend, database- MySQl,backend-> Spring,Springboot
# MEVN Stack -> M-> MongoDb, E-> ExpressJs, R-> VueJs, N-> NodeJs

# %%
# .java -> .class -> output

# %%
Python:
    1.Interpreted Programming
    2.Interactive Programming language
    3.Easy to learn 
    4.Dynamically typed programming(to make program simple)
    5.Cross Platform(Different OS)
    6.Open Source(Free anyone can download)
    7.OOPS Concept -> Provide Security
    8.Is not much Secure (more builtin libraries)
    9.More builtin libraries/Builtin methods
#     10.Exception Handling

# %%
print(10)
print(a)
# Out:
# 10
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 print(10)
# ----> 2 print(a)
#
# NameError: name 'a' is not defined

# %%
variables
c-> 4 different -> Primitive(int,float,char), Derived(Arrays,Pointers,Functions), Userdefined(Structures,Unions,Enums), Void(returns nothing) 
Datatypes:
    5 types of datatypes:
1. Number Datatype --> int,float,complex
2. Sequence Datatype -> string,list,tuple,range 
3. Map Datatype -> Dictionary
4. Set Datatype -> set,frozenset
5. Boolean -> True,False

# %%
# realnumber+imaginarynumber(j)
# # 4+2j

# %%
# # 1.Number datatype
# int,float,complex
# printf("Enter a value");
# scanf("%d",&a);
a=int(input("Enter a value: "))
print(a)
# to check the type of datatype we have method type
print(type(a))

b=float(input("Enter a value: "))
print(b)
print(type(b))

c=complex(input("Enter a value: "))
print(c)
print(type(c))
# Out:
# Enter a value: 10
# 10
# <class 'int'>
# Enter a value: 10.6666666
# 10.6666666
# <class 'float'>
# Enter a value: 4+2j
# (4+2j)
# <class 'complex'>

# %%
# # print()
# 2. format literals
# 3. Format Specifiers
# 4. Format method

a=10
b=20.5
c=14
print(a,b)
print(f"{a} {b}")
print("%d %.2f %d" %(a,b,c))
print("{1} {0} {2}".format(b,a,c))
# Out:
# 10 20.5
# 10 20.5
# 10 20.50 14
# 10 20.5 14

# %%
# parameters inside the print function
# print(group of objects,sep="",end="",file=sys.stdout,flush=False)
a=10
b=20
c="Revanth"
# print(a,b,c,d,e,f,------n,"This is",---------------------------)
#print("Revanth","helo","hai","world",a,b,c,"Revanth",a,b,c,"Revanth",a,b,c,"Revanth",a,b,c,"Revanth",a,b,c,"Revanth",a,b,c,"Revanth",a,b,c,"Revanth",a,b,c,"Revanth",a,b,c,"Revanth",a,b,c,"Revanth",a,b,c,"Revanth",a,b,c,"Revanth",a,b,c,"Revanth",a,b,c,"Revanth",a,b,c,"Revanth",a,b,c,"Revanth",a,b,c,"Revanth",a,b,c,"Revanth",a,b,c,"Revanth",a,b,c,"Revanth",a,b,c,"Revanth",a,b,c,"Revanth",a,b,c,"Revanth",a,b,c,"Revanth",a,b,c,"Revanth",a,b,c,"Revanth",a,b,c,"Revanth",a,b,c,"Revanth",a,b,c,"Revanth",a,b,c,"Revanth",a,b,c,"Revanth",a,b,c,"Revanth",a,b,c,"Revanth",a,b,c,)
# print(a,b,c)
# By Deefault Separator is space 
# By Default end value is newline
print(a,b,c,sep="->",end="->")

print("hello")
# a->b
# Out:
# 10->20->Revanth->hello

# %%
# Operators
# 1. Arthimetic -> +,-,*,/, //, **, %
# 2. Relational Operators => ==,>,<,>=,<=,!=
# 3. Assignment Operators => += , -=, *= , /= ,%=, //=, **==
# 4. Logical Operators -=> and or not
# 5. Bitwise Operators=> &, | , ^, >> , <<
# 6. identity operators -> is is not
# 7. membership operator -> in not in 
# Unary Operators -> ++, -- it does not support
# Ternary Operators -> Does not Support
# Membership Operators
# Identity Operators

a=10
b=3
print(10>>2)
# 10>>2
# a=a+b 
# a+=b
print(a//b) # // Floor Division
#**-
print(a**3) # ** for exponentiation/power
# Out:
# 2
# 3
# 1000

# %%
0OOPS-> Provide Security
collection of classes and objects ->
class Bank:
    Store the data 
Bank-> Accountnumber, Account password, ATMpin, Balance

# %%
print('hello)
print("Hello")
# Out:
#   Cell In[1], line 1
#     print('hello)
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print("hello")
print("hello2")  ONLY ONCE AT A TIME AND CONVERTED TO BINARY LANGUAGE(0,1) -> Compiler
print("hello3")  Each and every line will CONVERTED TO BINARY LANGUAGE(0,1) -> Interpreter (takes some time)

# %%
# English -> Machine level language(binary language)
Convertors ->1. compiler -> High level -> Machine (0,1) -> Only one time Ex: C, Java, JS, Perl,Ruby
            2. Interpreter High level -> Machine -> Each and every line once Ex: Java, Python
#            3. Assembler -> Assembly Level -> Machine 
# a+b
# ADD A,B

# %%
C -> Compiled
10 lines 
java -> Compiled and intrepreted

# %%
float a;
float a;
float a;
a=float(input())

# %%
Web pages -> are the pages for reading (No updated)
web applications()-> we can interact with them (Whatsup,youtube)

# %%
HTML+ CSS + JS (Dynamic Data) = Webdevelppment

# %%
# two more operators
1. identity operator  -> is , is not
2. Membership Operator -> in , not in

output is a boolean value - True, False

# %%
# identity operators is used to check whether two values are present in same memory allocation or not
# int *p=&a;
# printf("%d",p)
a="4A10"
b="3A10"
print(id(a))
print(id(b))
print(a is b)
print(a is not b)

c=12
d=12
# for integers it is same addrress
# for floating different
print(c is d)
print(c is not d)
# Out:
# 1974348791408
# 1974348773488
# False
# True
# True
# False

# %%
# Comment -> 1. single line comment - #
# 2. multi line comment - ''''''

# %%
# Membership Operator
# is used to check whether the value is present in the sequence or not
# seqquence - list,string, tuple,range
a="revanth" # String
print('ea' in a)
print('ea' not in a)

k=[1,2,3,4] # list
print(1 in k)

l=(1,2,3,4,5) # Tuple
print(5 in l)
# Out:
# False
# True
# True
# True

# %%
a=complex(input("Enter a value: "))
print(a)
