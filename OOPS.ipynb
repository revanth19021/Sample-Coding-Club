# %%
# OOPS Concept
3 procedural - c
 object based - javascript
object oriented  - python, java , c++(c with classes),simula67

# %%
# OOPS - > Every thing is inside classes
class is a collection of attributes (methods,variables,constructors)
blue print of an object (real world entity)
object - instance to a class

# %%
class a:
    pass # keyword 
obj=a()

# %%
# variables, methods, constructors
# __init__()  magical methods / dunder methods
# method - 
def functionname(parameters):
    
functioncall(arguments)

# %%
def functionname(parameters):
    '''Documentation string'''
    block of statements
    return
functioncall(arguments)

# %%
def running(a,b):
    '''this is running'''
    print(a,b)
running(5)
print(running.__doc__)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       2     '''this is running'''
#       3     print(a,b)
# ----> 4 running(5)
#       5 print(running.__doc__)
#
# TypeError: running() missing 1 required positional argument: 'b'

# %%
# Types of arguments 
# 1. positional arguments
# 2. keyword arguments
# 3. default arguments
4. variable length
5. keyword variable length

# %%
def hello(*a):
    print(a)
hello(1,2,3,4,6,7,8)

def hello1(**a):
    print(a)
hello1(a="revanth",b=5)
# Out:
# (1, 2, 3, 4, 6, 7, 8)
# {'a': 'revanth', 'b': 5}

# %%
def hello(c,a=8,b):
    print(a,b,c)
hello(6,8)
# Out:
#   Cell In[9], line 1
#     def hello(c,a=8,b):
#                     ^
# SyntaxError: non-default argument follows default argument

# %%
def hello(a,b):
    print(a,b)
hello(b=int(input()))
# Out:
# 6
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 def hello(a,b):
#       2     print(a,b)
# ----> 3 hello(b=int(input()))
#
# TypeError: hello() missing 1 required positional argument: 'a'

# %%
class A:
    # class variable or constructor variable
    # refer with default defaultparameter.variablename
    def __init__(self,a,b):
        # a.firstvalue=a
        # a.secondvalue=b
        # b.firstvalue=a
        self.firstvariable=a
        
        
    def method1(revanth,a,b): #revanth=a
        #revanth=b
        #revanth=c
        print("method1",a,b)
a=A()
a.method1()
b=A()
b.method1()
c=A()
c.method1()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 5
#       3         print("method1")
#       4 a=A()
# ----> 5 a.method1()
#       6 b=A()
#       7 b.method1()
#
# TypeError: A.method1() takes 0 positional arguments but 1 was given

# %%
class Run:
    name="revanth"
    # constructor classvariables
    def __init__(a,b,c):
        a.second=b
        a.third=c
    def method1(l,a,b):
        print(l.name,l.second,l.third)
        print(a,b)

a=Run(1,2)
a.method1("hello","world")
# Out:
# revanth 1 2
# hello world

# %%
# Inheritance, Polymorphism, abstraction , encapsulation

class parent:
    pass
class child(parent):
    pass
a=child()

# %%
1. single 2. multilevel 3. multiple 4. herarical 5. hybrid
